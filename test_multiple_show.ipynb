# %%
import matplotlib.pyplot as plt
import numpy as np

# %matplotlib inline

# %%
data = np.random.randn(2, 100)

# %%
fig, (ax1, ax2) = plt.subplots(1, 2)

# %% [markdown]
# # Doesn't work :(

# %%
ax1.plot(*data)
fig.show()
# Out:
# /Users/choldgraf/Dropbox/github/forks/python/matplotlib/lib/matplotlib/figure.py:405: UserWarning: matplotlib is currently using a non-GUI backend, so cannot show the figure
#   "matplotlib is currently using a non-GUI backend, "

# %%
ax2.scatter(*data)
fig.show()
# Out:
# /Users/choldgraf/Dropbox/github/forks/python/matplotlib/lib/matplotlib/figure.py:405: UserWarning: matplotlib is currently using a non-GUI backend, so cannot show the figure
#   "matplotlib is currently using a non-GUI backend, "

# %% [markdown]
# # Works

# %%
fig, (ax1, ax2) = plt.subplots(1, 2)

# %%
ax1.plot(*data)
fig

# %%
ax2.scatter(*data)
fig
